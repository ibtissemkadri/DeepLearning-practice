# %% [markdown]
# #### In this notebook we are going to build Arabic Names generator using char-level language model

# %%
import tensorflow as tf
import numpy as np
import random
import pandas as pd
from keras import backend as K
from keras.models import Sequential, Model
from keras.optimizers import Adam, RMSprop
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, Dropout, LSTM, Reshape, TimeDistributed, Activation
from keras.callbacks import LambdaCallback
from keras.utils import np_utils

# %% [markdown]
# # Loading and preprocessing data

# %%
data = open('arabic_names.txt', 'r').read()
data= data.lower()
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('Total characters: ',data_size)
print('Unique characters: ',vocab_size)
# Out:
# Total characters:  6659
# Unique characters:  42

# %% [markdown]
# ## Dictionary

# %% [markdown]
# we create a python dictionary to map each character to an index from 1-42.

# %%
char_to_ix = { ch:i+1 for i,ch in enumerate(sorted(chars)) }
ix_to_char = { i+1:ch for i,ch in enumerate(sorted(chars)) }# the 0 will be reserved to the one timestamp delay 
print(ix_to_char)
# Out:
# {1: '\n', 2: ' ', 3: 'ء', 4: 'آ', 5: 'أ', 6: 'ؤ', 7: 'إ', 8: 'ئ', 9: 'ا', 10: 'ب', 11: 'ة', 12: 'ت', 13: 'ث', 14: 'ج', 15: 'ح', 16: 'خ', 17: 'د', 18: 'ذ', 19: 'ر', 20: 'ز', 21: 'س', 22: 'ش', 23: 'ص', 24: 'ض', 25: 'ط', 26: 'ظ', 27: 'ع', 28: 'غ', 29: 'ف', 30: 'ق', 31: 'ك', 32: 'ل', 33: 'م', 34: 'ن', 35: 'ه', 36: 'و', 37: 'ى', 38: 'ي', 39: 'َ', 40: 'ُ', 41: 'ِ', 42: 'ّ'}

# %% [markdown]
# ## Generate output and input data

# %%
with open("arabic_names.txt") as f:
        examples = f.readlines()
examples = [x.lower().strip() for x in examples] # list of names in the input data
num_examples=len(examples)

# %% [markdown]
# At every time-step  $t$, we have $y^{\langle t \rangle} = x^{\langle t+1 \rangle}$.

# %%
X=[]
Y=[]
max_len=0
for j in range(num_examples):
  if len(examples[j])>max_len:
    max_len=len(examples[j])+1 # +1 for the end of word character "\n"
  ex_x = [0]+[char_to_ix[ch] for ch in examples[j]] # we add [0] to delay target by one timstamp
  ex_y = ex_x[1:]+[char_to_ix['\n']]# the target is the input delayed by one timestamp
  X.append(ex_x)
  Y.append(ex_y)

# %%
X = pad_sequences(X, maxlen=max_len, padding='post', value=0) # setting all the inputs to the same length (=max length of a name)
Y = pad_sequences(Y, maxlen=max_len, padding='post', value=0)

X=tf.one_hot(X, vocab_size+1, axis=2) # converting sequences of characters indexes to one hot vectors
Y=tf.one_hot(Y, vocab_size+1,  axis=2)# the +1 in vocab_size+1 refers to the delay character
sess = tf.Session()
X=X.eval(session=sess)
Y=Y.eval(session=sess)
#Y=Y.reshape(Y.shape[1], Y.shape[0], Y.shape[2])
X.shape, Y.shape
# Out:
# ((1186, 14, 43), (1186, 14, 43))

# %% [markdown]
# # Character-level language model for name generation

# %% [markdown]
# At each time-step, the RNN tries to predict what is the next character given the previous characters.

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(max_len, vocab_size+1), return_sequences=True))
model.add(TimeDistributed(Dense(vocab_size+1)))
model.add(TimeDistributed(Activation('softmax')))
optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 14, 128)           88064
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 14, 43)            5547
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 14, 43)            0
# =================================================================
# Total params: 93,611
# Trainable params: 93,611
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This function is to sample a sequence of characters according to a sequence of probability distributions output of the RNN.

# %%
def sample(epoch, logs):
  char_to_ix["\t"]=0
  if epoch%2==0 and epoch !=0:
    print('----- Generating text after Epoch: %d' % epoch)
    for i in range(0,10):
      stop=False
      counter=1
      target_seq = np.zeros((1, max_len, vocab_size+1))
      # Create the one-hot vector x for the first character (initializing the sequence generation)
      target_seq[0, 0, 0] = 1.
      ch=''
      while stop == False and counter < 10:#We'll stop if we reach 10 characters or we detect \n
        #sample the data
        # At each time-step, sample a character from a probability distribution and append
        probs = model.predict_proba(target_seq, verbose=0)[:,counter-1,:]
        c= np.random.choice(['\t']+sorted(list(chars)), replace =False, p=probs.reshape(vocab_size+1))
        if c=='\n':
          stop=True
        else:
          ch=ch+c
          target_seq[0,counter , char_to_ix[c]] = 1.
          counter=counter+1
      print(ch)

# %%
# fitting the model
print_callback = LambdaCallback(on_epoch_end=sample)
model.fit(X, Y, batch_size=32,epochs=250, callbacks=[print_callback])
# Out:
# Epoch 1/250
# 1186/1186 [==============================] - 2s 2ms/step - loss: 1.4663
# Epoch 2/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 1.1522
# Epoch 3/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 1.0232
# ----- Generating text after Epoch: 2
# هاد
# جوبةةيزلو
# حو
# ىلائلأثزي
# وبئمسؤغبت
# ثوريدغ
# سجيض
# اعن
# بياّاترجَ
# سفيم
# Epoch 4/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 1.0658
# Epoch 5/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.9598
# ----- Generating text after Epoch: 4
# روروديلال
# جورينيل
# سماننيت
# نيروهت
# منوتن
# جولوليميل
# حُويّة
# نامني
# ربجي
# رطليليم
# Epoch 6/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.9372
# Epoch 7/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.9088
# ----- Generating text after Epoch: 6
# تجيف
# فرتاريناد
# بهيا
# مجارة
# جوشية
# فاوية
# أيسور
# ن ارلة
# دارادان
# فجلة
# Epoch 8/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.8921
# Epoch 9/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.8711
# ----- Generating text after Epoch: 8
# جرل
# 	بالين
# فيلفان
# سمى
# نوهر
# بَس
# إيتور
# صائل
# أحبُِزسرت
# مسر
# Epoch 10/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.8518
# Epoch 11/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.8283
# ----- Generating text after Epoch: 10
# أيسزي
# أمهبة
# مى
# أسرد
# لولية
# صفوض
# رولان
# هنال
# حهطي
# شَشل
# Epoch 12/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.8076
# Epoch 13/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.7870
# ----- Generating text after Epoch: 12
# مرؤم
# رمين
# سمرسانر
# نيمة
# كريم
# طانر
# غيلاء
# فؤدة
# سيل
# جيثنارا
# Epoch 14/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.7646
# Epoch 15/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.7446
# ----- Generating text after Epoch: 14
# وسيل
# نزار
# ثاري
# بَاد
# ميسر
# أمينة
# جاله
# مير
# مارد
# كور
# Epoch 16/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.7252
# Epoch 17/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.7071
# ----- Generating text after Epoch: 16
# فورية
# نهاب
# يأسار
# أسار
# حَنز
# ضحى
# حارثم
# أنجال
# يسر
# نايفة
# Epoch 18/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6894
# Epoch 19/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6765
# ----- Generating text after Epoch: 18
# لوصى
# ميلاء
# نجدى
# إسماعيل
# تُهارة
# فيكتور
# رية
# سحمى
# فعت
# أسمى
# Epoch 20/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6622
# Epoch 21/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6533
# ----- Generating text after Epoch: 20
# طانر
# تارينا
# طهني
# عوني
# جوليانا
# سمراحة
# ساندا
# منال
# لانيس
# غفران
# Epoch 22/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6432
# Epoch 23/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.6350
# ----- Generating text after Epoch: 22
# شوس
# ناتايا
# كلود
# صفوت
# أنة
# كانيا
# وفيق
# نالم
# معتصم
# نادية
# Epoch 24/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6277
# Epoch 25/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6230
# ----- Generating text after Epoch: 24
# إيزيد
# أميني
# أوليفيا
# مهند
# ساحنيا
# عمير
# جورية
# ززير
# سونيا
# بَنان
# Epoch 26/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6145
# Epoch 27/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6110
# ----- Generating text after Epoch: 26
# لويسي
# فيروز
# فخخر
# زبير
# طه
# بيكوء
# وهاد
# إسلام
# وعود
# 	نعف
# Epoch 28/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6078
# Epoch 29/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.6037
# ----- Generating text after Epoch: 28
# خاسلين
# حُسيمة
# مارينا
# قسمة
# ميران
# سانيا
# أفا
# ليال
# تقاء
# فلة
# Epoch 30/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5995
# Epoch 31/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5961
# ----- Generating text after Epoch: 30
# نافعة
# شضالة
# رلمة
# ثابت
# نسمة
# مرغد
# ميساء
# فياض
# بيعب
# آسمة
# Epoch 32/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5945
# Epoch 33/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5928
# ----- Generating text after Epoch: 32
# نور
# صفي
# أمن
# أُسامة
# مديّاد
# رميساء
# فاروق
# عالية
# مينا
# علا
# Epoch 34/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5885
# Epoch 35/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5895
# ----- Generating text after Epoch: 34
# ريا
# ريدة
# لطيفة
# وضاح
# ساراي
# مارك
# ميساء
# مارتين
# حَسّان
# نامق
# Epoch 36/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5850
# Epoch 37/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5844
# ----- Generating text after Epoch: 36
# مرمد
# حاتم
# مية
# وهيب
# أزاير
# نعيم
# حَكم
# فيرجا
# نبيه
# ارتواء
# Epoch 38/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5793
# Epoch 39/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5825
# ----- Generating text after Epoch: 38
# عُدي
# جويرية
# هزان
# وجيه
# وضاح
# عز
# رامد
# لم الك
# ظافر
# وجدان
# Epoch 40/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5778
# Epoch 41/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5772
# ----- Generating text after Epoch: 40
# شناد
# سيلينا
# نجوى
# حبيب
# مايل
# صلاح
# فريت
# فرح
# زايدة
# إكرنا
# Epoch 42/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5769
# Epoch 43/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5768
# ----- Generating text after Epoch: 42
# المُطتز ل
# ألحاء
# بَكل
# سماحة
# جالا
# حوراء
# تولين
# سلام
# سسينان
# عتان
# Epoch 44/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5749
# Epoch 45/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5746
# ----- Generating text after Epoch: 44
# نُيفاء
# وصال
# يولاند
# ترنيم
# روفينة
# أشرف
# رغدة
# حِندر
# نجيب
# بَلسم
# Epoch 46/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5744
# Epoch 47/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5672
# ----- Generating text after Epoch: 46
# سلهسة
# ارتواء
# فصر
# وحيدة
# ميساء
# جهزاد
# شروق
# الفلاء
# أنجيلا
# لورانس
# Epoch 48/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5709
# Epoch 49/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5717
# ----- Generating text after Epoch: 48
# مارك
# بهجة
# صيفان
# ديفيد
# رَسل
# ناثان
# ليقا
# بِشارة
# رأفة
# جِنان
# Epoch 50/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5699
# Epoch 51/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5700
# ----- Generating text after Epoch: 50
# حِسمت
# ساندي
# نسيم
# إليسا
# سبُد
# نبيلة
# ثناء
# جديل
# مروان
# عيسي
# Epoch 52/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5707
# Epoch 53/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5652
# ----- Generating text after Epoch: 52
# وماء
# بوار
# تِبر
# شمس
# دوئيل
# تَرف
# زيد
# زكريا
# أم كُلثوم
# بِلال
# Epoch 54/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5672
# Epoch 55/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5659
# ----- Generating text after Epoch: 54
# جولي
# فرانسوا
# أشرف
# عفاف
# لوما
# أفاق
# أيرا
# ميخائيل
# شارل
# فضل
# Epoch 56/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5647
# Epoch 57/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5634
# ----- Generating text after Epoch: 56
# فريال
# ميلسيا
# مجدي
# أجول
# جفهان
# معاذ
# ت
# مخدي
# حارس
# سمعان
# Epoch 58/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5653
# Epoch 59/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5645
# ----- Generating text after Epoch: 58
# حوّاء
# بِنان
# تاح
# رة
# جورية
# غسان
# نيفين
# دينار
# زهو
# إسراء
# Epoch 60/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5639
# Epoch 61/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5637
# ----- Generating text after Epoch: 60
# آدم
# نضال
# كادي
# أمل
# هدايا
# لويس
# سينار
# جِنان
# سكينة
# نعيمة
# Epoch 62/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5635
# Epoch 63/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5611
# ----- Generating text after Epoch: 62
# حنّا
# نيفاد
# شادية
# نايك
# بارين
# هاني
# تُركي
# نهاد
# زهو
# رياض
# Epoch 64/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5603
# Epoch 65/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5619
# ----- Generating text after Epoch: 64
# بَندر
# صباح
# م
# نيرة
# شهيرة
# سلام
# شنيف
# ديمار
# شانتال
# شاهين
# Epoch 66/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5618
# Epoch 67/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5601
# ----- Generating text after Epoch: 66
# عملي
# أميرة
# جاسم
# أُميمة
# غقاد
# زهير
# صفوت
# ضوى
# سماح
# بِلال
# Epoch 68/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5602
# Epoch 69/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5594
# ----- Generating text after Epoch: 68
# فدائي
# علوي
# نيكول
# سِيم
# حايب
# ذهف
# ظافر
# هدا
# ريما
# جُود
# Epoch 70/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5592
# Epoch 71/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5575
# ----- Generating text after Epoch: 70
# آمنة
# مارل
# إلهام
# إلهامي
# بِيسان
# مليكة
# حَمّود
# صاحود
# شويكار
# كلير
# Epoch 72/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5578
# Epoch 73/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5585
# ----- Generating text after Epoch: 72
# نضال
# قصر
# مادلين
# هنا
# تنسيم
# أنسر
# ناير
# خولة
# هناء
# داغر
# Epoch 74/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5577
# Epoch 75/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5597
# ----- Generating text after Epoch: 74
# يام
# بَندر
#
# ينال
# أسِيف
# واعد
# زبيدة
# قابيل
# مريم
# وميض
# Epoch 76/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5568
# Epoch 77/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5570
# ----- Generating text after Epoch: 76
# سلمى
# صالحة
# أزميرالدا
# ليى
# دائب
# للي
# جويرية
# صباح
# ذهب
# أمير
# Epoch 78/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5558
# Epoch 79/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5563
# ----- Generating text after Epoch: 78
# إحسان
# نجلاء
# حماد
# إيميلي
# ريما
# حَنين
# شارل
# ريما
# يمنى
# أنوار
# Epoch 80/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5547
# Epoch 81/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5557
# ----- Generating text after Epoch: 80
# رميس
# فاتنة
# طهرة
# زكريا
# ونس
# ريّان
# نورسين
# أليس
# جُمان
# جوران
# Epoch 82/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5537
# Epoch 83/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5557
# ----- Generating text after Epoch: 82
# مكة
# غيداء
# ثناء
# منى
# بدير
# شهيرة
# جانوين
# هدير
# برَسء
# اشتسان
# Epoch 84/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5564
# Epoch 85/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5548
# ----- Generating text after Epoch: 84
# جالا
# جالا
# ضحى
# عثمان
# داور
# عهد
# أمينة
# قاسم
# براء
# ميسرة
# Epoch 86/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5540
# Epoch 87/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5546
# ----- Generating text after Epoch: 86
# أنطوني
# حَمد
# إقبال
# ارتواء
# منيرة
# نعيمة
# نجا
# مانويل
# وحد
# جوري
# Epoch 88/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5533
# Epoch 89/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5538
# ----- Generating text after Epoch: 88
# سكون
# مريم
# بِرياس
# ناثان
# وداد
# أفيق
# بيبرس
# فيليب
# ّالر
# بِربارة
# Epoch 90/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5538
# Epoch 91/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5533
# ----- Generating text after Epoch: 90
# معتت
# باسيل
# دانية
# ريتا
# أمينة
# نابغ
# شريف
# جايكوب
# اميسون
# اوتفان
# Epoch 92/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5529
# Epoch 93/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5518
# ----- Generating text after Epoch: 92
# بَسمات
# رفقة
# جورج
# نور
# رفقة
# رخلا
# سام
# كادي
# حوّاء
# ميلاء
# Epoch 94/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5527
# Epoch 95/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5512
# ----- Generating text after Epoch: 94
# ألبِرت
# آسية
# ماجي
# داليدا
# وديعة
# رشا
# نازك
#
# سالم
# وضاح
# Epoch 96/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5524
# Epoch 97/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5515
# ----- Generating text after Epoch: 96
# جايكوب
# تيمور
# نهى
# سونا
# رتّالة
# تيّم
# جورية
# حَفصة
# حامد
# فاروق
# Epoch 98/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5522
# Epoch 99/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5503
# ----- Generating text after Epoch: 98
# ملحم
# عالف
# نورما
# صالح
# كحير
# إشراق
# البشير
# نوران
# تحية
# فراس
# Epoch 100/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5515
# Epoch 101/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5509
# ----- Generating text after Epoch: 100
# وضّاء
# ضيلة
# أشهب
# استمان
# ماهينور
# كريستين
# نعمث
# عزت
# وائل
# ولجاء
# Epoch 102/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5514
# Epoch 103/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5508
# ----- Generating text after Epoch: 102
# غُزيل
# ميسر
# إليزابيث
# دينا
# ساهر
# نديم
# نرمين
# صفواد
# طارق
# وديع
# Epoch 104/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5496
# Epoch 105/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5507
# ----- Generating text after Epoch: 104
# جُود
# زينب
# نيماد
# أليف
# نيفادا
# ليديا
# ميسرة
# ماجش
# ريم
# عماد
# Epoch 106/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5504
# Epoch 107/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5500
# ----- Generating text after Epoch: 106
# خرفان
# تامر
# فراس
# وديعة
# هجرس
# رشدي
# عابد
# سينار
# جروان
# ماريهان
# Epoch 108/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5494
# Epoch 109/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5491
# ----- Generating text after Epoch: 108
# حُذيفة
# إلهامي
# يسري
# صفاء
# شرمي
# مؤمن
# بُدور
# مايسة
# يحيى
# سيف
# Epoch 110/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5495
# Epoch 111/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5485
# ----- Generating text after Epoch: 110
# نجيب
# شويكار
# سكاء
# رباب
# وفيق
# ميلاد
# جقال
# كلارا
# جيسيكا
# أكرم
# Epoch 112/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5492
# Epoch 113/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5472
# ----- Generating text after Epoch: 112
# منار
# بوجاء
# عزام
# جولين
# جَوان
# عايدة
# مراد
# مرقس
# بِلال
# محيي
# Epoch 114/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5483
# Epoch 115/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5479
# ----- Generating text after Epoch: 114
# ِياس
# جودي
# أماندا
# نانيس
# روميو
# رى
# دينا
# زهو
# فريدريك
# ودود
# Epoch 116/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5500
# Epoch 117/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5488
# ----- Generating text after Epoch: 116
# ليلى
# جُود
# علا
# مغنيا
# إخلاص
# مايكل
# حاجم
# بُثَينة
# إيزيلي
# جُلنار
# Epoch 118/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5477
# Epoch 119/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5474
# ----- Generating text after Epoch: 118
# إيزابيل
# وديعة
# سعيد
# بُدور
# جعفر
# ولاء
# هاشي
# جليل
# نيل
# رلية
# Epoch 120/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5481
# Epoch 121/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5476
# ----- Generating text after Epoch: 120
# البشير
# توماس
# سلامة
# كرمة
# رؤى
# فناي
# سلام
# جبر
# بَسمات
# آزاد
# Epoch 122/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5488
# Epoch 123/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5479
# ----- Generating text after Epoch: 122
# حنيفة
# سكينة
# جوليانا
# نوشا
# غالية
# نهيرة
# حَسنيت
# لينا
# خلود
# بَسمات
# Epoch 124/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5474
# Epoch 125/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5471
# ----- Generating text after Epoch: 124
# أدتظ
# جاسر
# نويرة
# رائف
# وهبة
# بَلسم
# أمير
# رشد
# عزام
# رميساء
# Epoch 126/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5474
# Epoch 127/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5474
# ----- Generating text after Epoch: 126
# مهيرة
# أمار
# خوري
# عياش
# لورانس
# هلال
# ؤوس
# أيوب
# معين
# نجاة
# Epoch 128/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5463
# Epoch 129/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5466
# ----- Generating text after Epoch: 128
# مُعاذ
# رقية
# سامر
# زايد
# واضح
# رامي
# حروي
# شادي
# بَتول
# سامحة
# Epoch 130/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5444
# Epoch 131/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5449
# ----- Generating text after Epoch: 130
# درويش
# شوق
# نوران
# ييرول
# عتى
# بنيامين
# تاج
# أمانة
# محفوظ
# رميز
# Epoch 132/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5423
# Epoch 133/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5441
# ----- Generating text after Epoch: 132
# جليلة
# نسيم
# أمنية
# رياة
# يزيد
# هداية
# أسمر
# مديحة
# وجنات
# علاء
# Epoch 134/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5446
# Epoch 135/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5460
# ----- Generating text after Epoch: 134
# مروة
# فتون
# زهور
# جرجس
# جيان
# جورية
# تَرف
# مارية
# سديم
# دان
# Epoch 136/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5459
# Epoch 137/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5439
# ----- Generating text after Epoch: 136
# سارفين
# أندرو
# شمس
# خيري
# دعد
# حَسنين
# حافظ
# ديفيد
# هادية
# كرمة
# Epoch 138/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5453
# Epoch 139/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5467
# ----- Generating text after Epoch: 138
# شفيق
# جوليا
# همام
# عزمي
# قمر
# حارب
# فرنسيس
# معتصم
# أمام
# نيكول
# Epoch 140/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5434
# Epoch 141/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5464
# ----- Generating text after Epoch: 140
# طاهر
# نصير
# ميار
# جروان
# تى
# أحمد
# حُور
# لوسي
# سهى
# مروان
# Epoch 142/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5460
# Epoch 143/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5459
# ----- Generating text after Epoch: 142
# علية
# نائلة
# مصطفى
# مروة
# ريم
# عفران
# منيب
# لبيب
# نوال
# باهر
# Epoch 144/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5458
# Epoch 145/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5454
# ----- Generating text after Epoch: 144
# ضياء
# مشيرة
# حوراء
# سكينة
# ثناء
# سامر
# شارلي
# سامنثا
# مروى
# زهر
# Epoch 146/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5463
# Epoch 147/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5457
# ----- Generating text after Epoch: 146
# الشيّماء
# داعد
# جمال
# صصفي
# صافيناز
# الحُسَين
# غانم
# راجع
# أنور
# مكة
# Epoch 148/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5446
# Epoch 149/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5448
# ----- Generating text after Epoch: 148
# أم كُلثوم
# شايع
# زياد
# مارينا
# عيسى
# ضاحي
# إيريني
# أوس
# منيف
# ؤير
# Epoch 150/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5444
# Epoch 151/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5436
# ----- Generating text after Epoch: 150
# كوثر
# ملكة
# زياد
# ساندرا
# طلعت
# أورهان
# تالا
# فدوة
# وائل
# أمل
# Epoch 152/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5443
# Epoch 153/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5452
# ----- Generating text after Epoch: 152
# لامار
# عايشة
# جولين
# صباح
# لامار
# أميم
# خلود
# تالا
# تيمور
# كلارا
# Epoch 154/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5446
# Epoch 155/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5444
# ----- Generating text after Epoch: 154
# كريستيان
# غالي
# سميحة
# بِجاد
# قسمت
# ألبِرت
# مُعاذ
# كاملة
# إفرونيا
# تهاني
# Epoch 156/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5455
# Epoch 157/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5435
# ----- Generating text after Epoch: 156
# بمارئيف
# صفية
# عيسى
# وديعة
# رنا
# نائلة
# نتى
# جاد
# سلام
# روبرت
# Epoch 158/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5428
# Epoch 159/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5439
# ----- Generating text after Epoch: 158
# نوال
# صبا
# مجدي
# جمال
# رانيا
# بِجاد
# نياف
# يوسف
# هدية
# نجاة
# Epoch 160/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5442
# Epoch 161/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5435
# ----- Generating text after Epoch: 160
# جيلان
# جاولينا
# هلال
# عتناي
# جولين
# أبانوب
# هيلة
# فياض
# جويرية
# إياس
# Epoch 162/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5431
# Epoch 163/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5441
# ----- Generating text after Epoch: 162
# هانية
# عبد العاي
# سيف
# درغام
# تامة
# يسر
# تَليد
# فتحي
# نايف
# يسري
# Epoch 164/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5435
# Epoch 165/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5423
# ----- Generating text after Epoch: 164
# ساندي
# شهاب
# شوق
# ناذيخين
# رهف
# زاهر
# جلسال
# منال
# كلير
# ضحى
# Epoch 166/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5432
# Epoch 167/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5418
# ----- Generating text after Epoch: 166
# َنادر
# غادة
# غيداء
# حازم
# علي
# فتناِ
# عُدي
# أنفال
# هانية
# أبانوب
# Epoch 168/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5442
# Epoch 169/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5426
# ----- Generating text after Epoch: 168
# يونان
# كريستين
# حافظ
# حساف
# قطوف
# علب
# سمر
# خنساء
# وخئي
# تنسيم
# Epoch 170/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5432
# Epoch 171/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5428
# ----- Generating text after Epoch: 170
# عصام
# علاء
# عزمي
# هبة
# نينا
# يسر
# إمتنان
# علي
# فصر
# رفقة
# Epoch 172/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5426
# Epoch 173/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5432
# ----- Generating text after Epoch: 172
# رتّالة
# جذرية
# سهى
# تَليد
# عزة
# فيهجب
# أسماء
# أمانيا
# جوليا
# ريناد
# Epoch 174/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5436
# Epoch 175/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5428
# ----- Generating text after Epoch: 174
# فيليب
# شفاء
# توماس
# دعد
# رفيف
# أبرار
# أسرار
# لويس
# شارل
# ماريهان
# Epoch 176/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5435
# Epoch 177/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5412
# ----- Generating text after Epoch: 176
# فلة
# إمام
# رؤوف
# صافي
# ّالح
# أنجيلا
# وئام
# هزاع
# بارين
# عيسى
# Epoch 178/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5418
# Epoch 179/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5435
# ----- Generating text after Epoch: 178
# علي
# باسِمة
# جمال
# عمر
# تميم
# رياض
# نورما
# رنا
# تَليد
# وثُسسل
# Epoch 180/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5417
# Epoch 181/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5422
# ----- Generating text after Epoch: 180
# حمزة
# فاتنة
# زينب
# حكرم
# تنسيم
# أنهار
# مريام
# أديب
# أجزين
# باديس
# Epoch 182/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5420
# Epoch 183/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5429
# ----- Generating text after Epoch: 182
# جيان
# حَسنات
# استفانوس
# سمية
# إسماعيل
# زليخة
# ة
# حُسني
# جَواد
# ريهام
# Epoch 184/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5419
# Epoch 185/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5426
# ----- Generating text after Epoch: 184
# نيكولا
# قدري
# وهاد
# وديع
# جوري
# ناصر
# نهى
# مُريد
# لطيف
# رفيدة
# Epoch 186/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5426
# Epoch 187/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5422
# ----- Generating text after Epoch: 186
# نيكول
# م
# بِربارة
# عايشة
# كنون
# ورد
# باهر
# تريز
# خالد
# إيزابيل
# Epoch 188/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5425
# Epoch 189/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5425
# ----- Generating text after Epoch: 188
# ريدة
# سمية
# وعد
# سينار
# بِجاد
# فيوليت
# هاشم
# سامية
# هديل
# زبيدة
# Epoch 190/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5419
# Epoch 191/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5417
# ----- Generating text after Epoch: 190
# قدري
# ثُريا
# مريام
# رفيدة
# ثابت
# شكري
# غلا
# حَكيمة
# أسيا
# أندراوس
# Epoch 192/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5423
# Epoch 193/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5422
# ----- Generating text after Epoch: 192
# مانويل
# آسية
# فلة
# وعد
# سحين
# وجدي
# ملك
# سلام
# نيكولاس
# يونس
# Epoch 194/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5423
# Epoch 195/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5419
# ----- Generating text after Epoch: 194
# أسماء
# غيداء
# هدى
# فيليب
# لقاء
# المُعتز ب
# شريفان
# رند
# ظبية
# صالح
# Epoch 196/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5414
# Epoch 197/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5419
# ----- Generating text after Epoch: 196
# حُسام
# شانتال
# هوري
# بِربارة
# رفيعة
# مارينا
# فهد
# جوليانا
# نافع
# إ
# Epoch 198/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5419
# Epoch 199/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5417
# ----- Generating text after Epoch: 198
# أوة
# إبراهيم
# مونيكا
# دان
# ياسين
# دلال
# زجير
# ليث
# ميلاد
# م
# Epoch 200/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5413
# Epoch 201/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5413
# ----- Generating text after Epoch: 200
# خصر
# ينال
# جون
# منيرة
# أوكتافيا
# يوحنا
# نيكولا
# حَسن
# أسعد
# سامنثا
# Epoch 202/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5412
# Epoch 203/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5415
# ----- Generating text after Epoch: 202
# ضوى
# عزة
# أمسرة
# إيريس
# نيل
# أمانة
# نهاد
# وعد
# ديمة
# فخر
# Epoch 204/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5413
# Epoch 205/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5408
# ----- Generating text after Epoch: 204
# أشجان
# مروى
# دليلة
# مناف
# ندهم
# ناهد
# بجاد
# عودة
# كارين
# مهرة
# Epoch 206/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5412
# Epoch 207/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5415
# ----- Generating text after Epoch: 206
# دنا
# همام
# سيمون
# غالي
# خولة
# طايل
# منال
# عنود
# سينار
# ضحى
# Epoch 208/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5419
# Epoch 209/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5407
# ----- Generating text after Epoch: 208
# أسِيف
# نويرة
# ماجدة
# حَيدي
# حَبَابة
# موسى
# داليا
# توما
# يونس
# أفراح
# Epoch 210/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5400
# Epoch 211/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5410
# ----- Generating text after Epoch: 210
# حيا
# ريما
# ورد
# كنعان
# غلا
# خالد
# ألحان
# علي
# أروى
# محياء
# Epoch 212/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5407
# Epoch 213/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5414
# ----- Generating text after Epoch: 212
# آسية
# وهبة
# أشهب
# آلاء
# بُشرى
# سكينة
# داييدا
# بَسنت
# إمام
# رميساء
# Epoch 214/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5411
# Epoch 215/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5402
# ----- Generating text after Epoch: 214
# شيرين
# مشيرة
# شانتال
# صافية
# أيوب
# عبد الرحي
# إدريس
# تَرسين
# أماني
# نيروز
# Epoch 216/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5418
# Epoch 217/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5391
# ----- Generating text after Epoch: 216
# نعمة
# إليزابيث
# حُور
# أديبة
# ريتا
# متى
# نادية
# جبريال
# بُدور
# خير
# Epoch 218/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5390
# Epoch 219/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5409
# ----- Generating text after Epoch: 218
# قابوس
# تَودُد
# رنا
# إباء
# أندرية
# ألفة
# طاهر
# زايد
# شنودة
# يوكابد
# Epoch 220/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5407
# Epoch 221/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5405
# ----- Generating text after Epoch: 220
# مروان
# أرسلان
# لديم
# ريدة
# شداد
# سحر
# عصمت
# إيلين
# نايا
# مختار
# Epoch 222/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5397
# Epoch 223/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5402
# ----- Generating text after Epoch: 222
# جوزفين
# وسام
# اماري
# سيمون
# دعد
# وديع
# حامد
# راسلمان
# كنزي
# رودين
# Epoch 224/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5311
# Epoch 225/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5341
# ----- Generating text after Epoch: 224
# حبيبة
# رسلان
# جيداء
# إسحاق
# درغام
# ساراي
# هداية
# هُيام
# مُريد
# صموئيل
# Epoch 226/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5381
# Epoch 227/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5399
# ----- Generating text after Epoch: 226
# أسرار
# لوديا
# عهد
# يوسف
# جوزفين
# جودي
# البشير
# جمعة
# زهور
# أريام
# Epoch 228/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5406
# Epoch 229/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5383
# ----- Generating text after Epoch: 228
# مانخين
# ريان
# نيرة
# جُمان
# جلاء
# نضال
# استفانوس
# هُديّن
# ياسر
# ة
# Epoch 230/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5397
# Epoch 231/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5408
# ----- Generating text after Epoch: 230
# عمار
# يسر
# نيكول
# شهيرة
# فؤاد
# نينا
# تَرتيل
# وافي
# علياء
# مايكل
# Epoch 232/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5396
# Epoch 233/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5404
# ----- Generating text after Epoch: 232
# صوفيا
# بُهدى
# روميو
# جسّار
# هنية
# خالدة
# اميرة
# صباح
# عزام
# تحية
# Epoch 234/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5399
# Epoch 235/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5394
# ----- Generating text after Epoch: 234
# شيرين
# جورجيت
# سيلينا
# إنعام
# زيان
# رياد
# إلهامي
# فيفيان
# زينة
# مايسة
# Epoch 236/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5375
# Epoch 237/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5396
# ----- Generating text after Epoch: 236
# فنإيا
# اعتماد
# جلاء
# كارم
# بِيسان
# شاهين
# سكون
# عمار
# إيريني
# حازم
# Epoch 238/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5391
# Epoch 239/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5371
# ----- Generating text after Epoch: 238
# أُميمة
# اعتماد
# هداية
# هُيام
# ربى
# إمتنان
# ريتاج
# شاهيناز
# ساهر
# يونس
# Epoch 240/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5359
# Epoch 241/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5373
# ----- Generating text after Epoch: 240
# نازلي
# نادي
# رباب
# رأفة
# ريتا
# جودي
# ناير
# روان
# مريام
# رويدة
# Epoch 242/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5364
# Epoch 243/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5378
# ----- Generating text after Epoch: 242
# إيزابيل
# مية
# جلال
# صفاء
# صافيناز
# مرغد
# ماجي
# لؤلؤة
# جسّار
# فاضلة
# Epoch 244/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5384
# Epoch 245/250
# 1186/1186 [==============================] - 2s 1ms/step - loss: 0.5407
# ----- Generating text after Epoch: 244
# تى
# جينا
# رامونا
# أسينات
# مازن
# تَقىّ
# تميم
# كاميليا
# تاج
# رومنو
# Epoch 246/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5374
# Epoch 247/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5364
# ----- Generating text after Epoch: 246
# نسرين
# وائل
# كارلا
# كامل
# حنيفة
# دينار
# حنان
# أفراح
# الشيّماء
# أمانة
# Epoch 248/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5348
# Epoch 249/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5367
# ----- Generating text after Epoch: 248
# ماريهان
# مارك
# ديمة
# جيان
# سلفستر
# ثامر
# جلال
# نوت
# أارت
# أنطوني
# Epoch 250/250
# 1186/1186 [==============================] - 1s 1ms/step - loss: 0.5373

# %% [markdown]
# As you can see at the first epochs the algorithm generated random characters but through the training it has started to generate plausible names :D
#
# Some of the names that I liked and that do not exist in the training data:
# جاولينا
# , بمارئيف
# ,اماري
